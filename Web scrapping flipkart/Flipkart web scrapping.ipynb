# %%
import requests
import bs4
import pandas as pd
import numpy as np

def phones(link):
    
    page=requests.get(link)                               #connecting with the link
    soup1=bs4.BeautifulSoup(page.content,"html.parser")
    cards=soup1.find_all("div",attrs={"class":"_1UoZlX"})
    list_page=[]
    final_list=[]
    for card in cards:
        name_div=card.find("div",attrs={"class":"_3wU53n"})
        name=name_div.text
        list_page.append(name)
        price_div=card.find("div", attrs={"class":"_2rQ-NK"})
        price=price_div.text
        list_page.append(price)
        rating_div=card.find("div", attrs={"class":"hGSR34"})
        rating=rating_div.text
        list_page.append(rating)
        final_list.append(list_page)        #list of phone name, price and rating saved
        list_page=[]
        #detail="{}  {}  {}".format(name,price,rating)
        #list_page.append(detail)
    return final_list
        
#Getting details of phone from 1st page
list_phone=[]
home_url="https://www.flipkart.com/"
link="https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1"
list_phone.extend(phones(link))

# Getting details of phone from 2nd to 10th page
for i in range(2,10):
    
    list_phone.extend(phones("https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}".format(i)))

# %%
def format_price(price):
    price = price[1:].split(',')
    return float("".join(price))

details = np.array(list_phone)             # Converting nested list to 2D array

Details_df = pd.DataFrame(details, columns=['Phone', 'Price', 'Rating'])   #converting array to dataframe

Details_df['Rating'] = Details_df.Rating.astype("float")

Details_df['Price'] = Details_df.Price.map(format_price)

Details_df.head()
# Out:
#                                    Phone    Price  Rating
# 0   Realme Narzo 10 (That White, 128 GB)  11999.0     4.5
# 1   Realme Narzo 10 (That Green, 128 GB)  11999.0     4.5
# 2   Redmi Note 8 Pro (Halo White, 64 GB)  15999.0     4.5
# 3  Redmi Note 8 Pro (Halo White, 128 GB)  16999.0     4.5
# 4         Lenovo K10 Plus (Black, 64 GB)  11499.0     4.1

# %%
print("Showing top 5 phones with price between 15000 and 20000 rupee and with rating more than 4.5")
print(" ")

print(Details_df[(Details_df.Price>14999) & (Details_df.Price<20001) & (Details_df.Rating>4.2)].sort_values(by='Rating', ascending = False)[:5])
# Out:
# Showing top 5 phones with price between 15000 and 20000 rupee and with rating more than 4.5
#
#                                    Phone    Price  Rating
# 2   Redmi Note 8 Pro (Halo White, 64 GB)  15999.0     4.5
# 84        Vivo S1 (Skyline Blue, 128 GB)  19990.0     4.5
# 81       Vivo S1 (Diamond Black, 128 GB)  16990.0     4.5
# 80        Vivo S1 (Skyline Blue, 128 GB)  16990.0     4.5
# 85       Vivo S1 (Diamond Black, 128 GB)  19990.0     4.5

# %%
query = input("Enter the minimum price, maximum price and minimum rating seperated by comma (,) ").split(",")
minn = float(query[0])-1
maxx = float(query[1])+1
rate = float(query[2])-0.1
print(Details_df[(Details_df.Price>minn) & (Details_df.Price<maxx) & (Details_df.Rating>rate)].sort_values(by='Rating', ascending = False))
# Out:
# Enter the minimum price, maximum price and minimum rating seperated by comma (,) 20000,30000,4.2
#                                                Phone    Price  Rating
# 130                 Redmi K20 (Carbon Black, 128 GB)  24999.0     4.5
# 94                 Vivo V15 Pro (Topaz Blue, 128 GB)  21099.0     4.5
# 96               Redmi K20 Pro (Pearl White, 128 GB)  26999.0     4.5
# 100                 Redmi K20 (Glacier Blue, 128 GB)  24999.0     4.5
# 174              Apple iPhone 6s (Space Grey, 32 GB)  29749.0     4.5
# 70              Redmi K20 Pro (Carbon Black, 128 GB)  26999.0     4.5
# 54                     Realme X (Space Blue, 128 GB)  20999.0     4.5
# 176       Vivo V17Pro (Midnight Ocean Black, 128 GB)  29499.0     4.5
# 52                    Realme X (Polar White, 128 GB)  20999.0     4.5
# 102                    Redmi K20 (Flame Red, 128 GB)  24999.0     4.5
# 190            OPPO Reno2 Z (Luminous Black, 256 GB)  27490.0     4.5
# 115             Redmi K20 Pro (Carbon Black, 256 GB)  29999.0     4.5
# 145                  Redmi K20 (Pearl White, 128 GB)  24999.0     4.5
# 126                  Redmi K20 (Carbon Black, 64 GB)  21999.0     4.5
# 135          Vivo V17 (Midnight Ocean Black, 128 GB)  24990.0     4.5
# 134             Vivo V17 (Glacier ice white, 128 GB)  24990.0     4.5
# 105                Honor 20 (Midnight Black, 128 GB)  22999.0     4.4
# 106                 Honor 20 (Sapphire Blue, 128 GB)  22999.0     4.4
# 88                  OPPO F15 (Unicorn White, 128 GB)  21990.0     4.4
# 75    Samsung Galaxy A51 (Prism Crush White, 128 GB)  25250.0     4.4
# 48    Samsung Galaxy A51 (Prism Crush Black, 128 GB)  25250.0     4.4
# 46     Samsung Galaxy A51 (Prism Crush Blue, 128 GB)  25250.0     4.4
# 28                  Vivo S1 Pro (Jazzy Blue, 128 GB)  20990.0     4.4
# 27                Vivo S1 Pro (Mystic Black, 128 GB)  20990.0     4.4
# 26                Vivo S1 Pro (Dreamy White, 128 GB)  20990.0     4.4
# 108               Samsung Galaxy A70 (White, 128 GB)  24299.0     4.3
# 124   Samsung Galaxy A51 (Prism Crush White, 128 GB)  27999.0     4.3
# 173    Samsung Galaxy A31 (Prism Crush Blue, 128 GB)  21999.0     4.2
# 169   Samsung Galaxy A31 (Prism Crush White, 128 GB)  21999.0     4.2
# 182                         Vivo NEX (Black, 128 GB)  26990.0     4.2
# 153    Samsung Galaxy A31 (Prism Crush Blue, 128 GB)  21999.0     4.2
# 149   Samsung Galaxy A31 (Prism Crush White, 128 GB)  21999.0     4.2
# 193   Samsung Galaxy A31 (Prism Crush White, 128 GB)  21999.0     4.2
# 13    Samsung Galaxy A31 (Prism Crush White, 128 GB)  21999.0     4.2
# 103    Samsung Galaxy A31 (Prism Crush Blue, 128 GB)  21999.0     4.2
# 129    Samsung Galaxy A31 (Prism Crush Blue, 128 GB)  21999.0     4.2
# 123   Samsung Galaxy A31 (Prism Crush White, 128 GB)  21999.0     4.2
# 111  Samsung Galaxy A70s (Prism Crush White, 128 GB)  25900.0     4.2
# 19     Samsung Galaxy A31 (Prism Crush Blue, 128 GB)  21999.0     4.2
# 99    Samsung Galaxy A31 (Prism Crush White, 128 GB)  21999.0     4.2
# 79     Samsung Galaxy A31 (Prism Crush Blue, 128 GB)  21999.0     4.2
# 73    Samsung Galaxy A31 (Prism Crush White, 128 GB)  21999.0     4.2
# 53     Samsung Galaxy A31 (Prism Crush Blue, 128 GB)  21999.0     4.2
# 49    Samsung Galaxy A31 (Prism Crush White, 128 GB)  21999.0     4.2
# 38    Samsung Galaxy A31 (Prism Crush Black, 128 GB)  21999.0     4.2
# 37     Samsung Galaxy A31 (Prism Crush Blue, 128 GB)  21999.0     4.2
# 199    Samsung Galaxy A31 (Prism Crush Blue, 128 GB)  21999.0     4.2
